# %%
import pandas as pd

# %%
df = pd.read_csv('iris.csv')

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
# Excluir linha 1
df.drop(0)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# 11                 4.8               3.4                1.6               0.2
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
df = df.drop(0)

# %%
df.shape
# Out:
# (149, 5)

# %%
# Excluir coluna
df = df.drop('target',axis=1)

# %%
df.shape
# Out:
# (149, 4)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# 11                 4.8               3.4                1.6               0.2
# ...

# %%
df = df.drop(['sepal length (cm)','sepal width (cm)'], axis=1)

# %%
df.shape
# Out:
# (149, 2)

# %%
df
# Out:
#      petal length (cm)  petal width (cm)
# 1                  1.4               0.2
# 2                  1.3               0.2
# 3                  1.5               0.2
# 4                  1.4               0.2
# 5                  1.7               0.4
# 6                  1.4               0.3
# 7                  1.5               0.2
# 8                  1.4               0.2
# 9                  1.5               0.1
# 10                 1.5               0.2
# 11                 1.6               0.2
# 12                 1.4               0.1
# 13                 1.1               0.1
# 14                 1.2               0.2
# 15                 1.5               0.4
# 16                 1.3               0.4
# 17                 1.4               0.3
# 18                 1.7               0.3
# 19                 1.5               0.3
# 20                 1.7               0.2
# 21                 1.5               0.4
# 22                 1.0               0.2
# ...

# %%
df = df.drop([1,4])

# %%
df.shape
# Out:
# (147, 2)

# %%
df
# Out:
#      petal length (cm)  petal width (cm)
# 2                  1.3               0.2
# 3                  1.5               0.2
# 5                  1.7               0.4
# 6                  1.4               0.3
# 7                  1.5               0.2
# 8                  1.4               0.2
# 9                  1.5               0.1
# 10                 1.5               0.2
# 11                 1.6               0.2
# 12                 1.4               0.1
# 13                 1.1               0.1
# 14                 1.2               0.2
# 15                 1.5               0.4
# 16                 1.3               0.4
# 17                 1.4               0.3
# 18                 1.7               0.3
# 19                 1.5               0.3
# 20                 1.7               0.2
# 21                 1.5               0.4
# 22                 1.0               0.2
# 23                 1.7               0.5
# 24                 1.9               0.2
# ...

# %%
# Exclui direto no dataset
df.drop(3, inplace=True)

# %%
df.shape
# Out:
# (146, 2)
